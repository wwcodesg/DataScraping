# %% [markdown]
# # Web Scraping 101
# ## The browser

# %%
from urllib.request import urlopen

# %% [markdown]
# Get a html page link:

# %%
URL = "http://pythonscraping.com/pages/page1.html"

# %% [markdown]
# Retrieve the page:

# %%
html = urlopen(URL)
html.read()
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
with urlopen(URL) as f:
    print(f.read(300).decode('utf-8'))
# Out:
# <html>
# <head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliqui

# %% [markdown]
# ## Anticipating http errors
# The web is messy, it pays to anticipate http errors and put in exceptions.
# Two common things that can go wrong:
#  * The page is not found on the server (404 Not Found)
#  * The server is not found (500 Internal Server Error)
#
# For list of possible error codes, see: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status

# %%
import urllib.request

# %%
URL2 = 'https://www.womenwhocode.com/singapore'

# %%
html = urlopen(URL2)

# %%
try:
    html = urlopen(URL2)
except urllib.error.HTTPError as e:
    print(e)
# Out:
# HTTP Error 403: Forbidden

# %% [markdown]
# ## https://
# ### HTTP over SSL
# For http over ssl, additional header information is required.

# %%
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
opener.open(URL2).read(300)
# Out:
# b"<!DOCTYPE html>\n<html>\n<head>\n<title>Singapore | Women Who Code</title>\n<meta description='Women Who Code is in Singapore! Check out our upcoming local events and join us for tech talks, hack days, and more.'>\n<meta content='width=extend-to-zoom, initial-scale=1' name='viewport'>\n<meta content='Wome"

# %% [markdown]
# ## Alternate Simpler method
# Using the requests library:
#
#     pip install requests

# %%
import requests
r = requests.get(URL2)
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<title>Singapore | Women Who Code</title>\n<meta description=\'Women Who Code is in Singapore! Check out our upcoming local events and join us for tech talks, hack days, and more.\'>\n<meta content=\'width=extend-to-zoom, initial-scale=1\' name=\'viewport\'>\n<meta content=\'Women Who Code | Singapore\' name=\'title\'>\n<meta content=\'on\' name=\'twitter:widgets:csp\'>\n<meta content=\'FGaOg6vwLaugx_vTv_3h-pdhXdAxIkFvE0RNVYn4WqI\' name=\'google-site-verification\'>\n<meta content=\'summary_large_image\' name=\'twitter:card\'>\n<meta content=\'@WomenWhoCode\' name=\'twitter:site\'>\n<meta content=\'Women Who Code | Singapore\' name=\'twitter:title\'>\n<meta content=\'We are a 501(c)(3) non-profit dedicated to inspiring women to excel in technology careers. 80,000 members strong in 60 cities spanning 20 countries &amp; counting\'>\n<meta content=\'https://www.filepicker.io/api/file/EymYlcDjTtKM2FVU0sx5/convert?fit=clip&amp;h=586&amp;w=1120\' name=\'twitter:image\'>\n<meta content=\'https://www.filepicker.io/api/file/EymYlcDjTtKM2FVU0sx5/convert?fit=clip&amp;h=586&amp;w=1120\' property=\'og:image\'>\n<meta content=\'https://www.womenwhocode.com/singapore\' property=\'og:url\'>\n<meta content=\'article\' property=\'og:type\'>\n<meta content=\'Women Who Code\' property=\'og:site_name\'>\n<meta content=\'Women Who Code | Singapore\' property=\'og:title\'>\n<meta content=\'Women Who Code is in Singapore! Check out our upcoming local events and join us for tech talks, hack days, and more.\' property=\'og:description\'>\n<meta content=\'https://www.womenwhocode.com/singapore\' property=\'fb:app_id\'>\n<link rel="stylesheet" media="all" href="https://www.womenwhocode.com/assets/application-f648c0b4240acc1b6695791425626fb331a30ee858c3e8a3e6a23f2411f06d7f.css" />\n<script src="https://www.womenwhocode.com/assets/application-3724ec78fe944b8499ccb9ad62ee640e7d1062222ef8e3deaf8969854be0baa4.js" media="all"></script>\n<script src="https://www.womenwhocode.com/assets/autotrack-a3adb9f2d23adbffb4ea8897ba0f7a9c563a325abe067609165391c92f608849.js" async="async"></script>\n<script src="https://static.filestackapi.com/v3/filestack.js"></script>\n<script src="https://checkout.stripe.com/checkout.js"></script>\n<script src="https://www.womenwhocode.com/assets/jquery.validate.min-55f4d0c0f36695675f74f8c7a9925c48f2ef50203c4c2ea28af2537eb4ba8e3f.js"></script>\n<script src="https://www.womenwhocode.com/assets/validate-additional-methods.min-59439ba6d7fa25b6eb47fe401c6cb2b4b68b9d0a8c2cd4051ee0bf5ede2f17c3.js"></script>\n<link rel="shortcut icon" type="image/x-icon" href="https://www.womenwhocode.com/assets/favicon-07d01b14a242ed521b883c54721f12b4e5c85bdb0f6afd20e009acff8f11cde8.ico" />\n<meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="0/zaMHTjTtwoc+XpnzQLHxmD+YW5kW696XbNIBDSt25CrIZ7YrCwT1uQG1G9srHm6dEhFRHpO/URVRUBIuFLkg==" />\n</head>\n<body class=\'controller_slugs\'>\n<div class=\'modal\' id=\'top-nav\'>\n<a class=\'logo\' data-event-action=\'logo\' data-event-category=\'header-nav\' href=\'/\'>\n<?xml version="1.0" encoding="utf-8"?>\n<!-- Generator: Adobe Illustrator 19.2.1, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->\n<svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" x="0px" y="0px" viewbox="0 0 466.5 249.3" style="enable-background:new 0 0 466.5 249.3;" xmlns:xlink="http://www.w3.org/1999/xlink" xml:space="preserve" class="logo">\n\n<g>\n\t<path id="path2989_9_" d="M39.9,244.2C12.3,231.6-2,202.1,0.2,162.1C2.7,117.4,28.9,88.2,67,87.5\n\t\tC93.1,87,94.1,88,94.1,113.4c0,12.1-0.9,22-2.1,22c-1.1,0-4.5-1.9-7.5-4.2c-10.9-8.3-26.7-2.7-33.7,11.9c-7.1,15-4.7,48,4.2,57.5\n\t\tc7.9,8.4,23.1,9.6,33.1,2.7c3.5-2.5,6.6-4,7-3.5c0.3,0.5-0.1,10.9-0.9,23.1c-1.4,20.7-2,22.2-8.5,24\n\t\tC72.6,250.5,51.1,249.3,39.9,244.2L39.9,244.2z M143.7,243.9C114,227.7,99,185.7,107.8,143.3c13.4-64.5,88.4-76.6,114.3-18.4\n\t\tc5.4,12.2,6.6,19.5,6.6,42.6c0.1,26-0.5,29.1-9.2,46.7c-12.1,24 ...

# %%
r.content[:300]
# Out:
# b"<!DOCTYPE html>\n<html>\n<head>\n<title>Singapore | Women Who Code</title>\n<meta description='Women Who Code is in Singapore! Check out our upcoming local events and join us for tech talks, hack days, and more.'>\n<meta content='width=extend-to-zoom, initial-scale=1' name='viewport'>\n<meta content='Wome"
